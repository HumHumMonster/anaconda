# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from LogicRegression import LogisticRegression

# %%
df_zhjtxx = pd.read_csv('./data/账户静态信息.csv')
df_train = pd.read_csv('./data/训练集标签.csv')

# %%
df_zhjtxx.head()
df_train.head()
# Out:
#                zhdh  black_flag
# 0  2029FF26D4E2CA79           0
# 1  09F5B90D46FB7CCE           1
# 2  E0C880EB18F4EFE8           1
# 3  ED8FFDCCF93C2F11           1
# 4  8D2F48B0BFC40AB2           1

# %%
df_train_merge = df_train.merge(df_zhjtxx , on='zhdh')

# %%
train_data = df_train_merge.sample(frac = 0.8) ;
test_data = df_train_merge.drop(train_data.index) ;

# %%
train_data.head()
# Out:
#                  zhdh  black_flag        khrq    khjgdh  xb  年龄
# 146  59FC66AC89B229D4           0  2017-02-06  B5B41FAC   0  45
# 518  794CB5AA45620E54           1  2019-09-07  A3C65C29   0  42
# 804  A883066E63BDD65E           1  2016-06-28  E2C0BE24   0  33
# 865  835C30B9EDC89BE8           0  2018-06-02  E7061188   1  32
# 875  B9F1E20314850980           0  2010-04-26  7EABE3A1   0  38

# %%
input_param_name = '年龄' ;
output_param_name = 'black_flag' ;

# %%
x_train = train_data[[input_param_name]].values ;
y_train = train_data[[output_param_name]].values ;

# %%
x_test = test_data[[input_param_name]].values ;
y_test = test_data[[output_param_name]].values ;

# %%
plt.scatter(x_train, y_train, label='Train data') ;
plt.scatter(x_test, y_test, label = 'Test data') ;
plt.xlabel(input_param_name) ;
plt.xlabel(output_param_name) ;
plt.show() ;

# %%
logistic_regression = LogisticRegression(x_train, y_train);

# %%
logistic_regression.data.shape
# Out:
# (960, 2)

# %%
num_iterations = 500 ;
learning_rate = 0.01 ;

# %%
(theta, cost_history) = linear_regression.train(alpha=learning_rate , num_iterations=num_iterations)

# %%
cost_history
# Out:
# [122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
#  122.5,
# ...

# %%
theta
# Out:
# array([[0.]])
